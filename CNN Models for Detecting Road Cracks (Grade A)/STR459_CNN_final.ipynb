# %% [markdown]
# ## STR459: AI and robotics

# %% [markdown]
# #### Setting up the project

# %%
# Install packages
pip install tensorflow pandas matplotlib scikit-learn seaborn

# %%
# Import libraries:
import os
import shutil
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.layers import GlobalAveragePooling2D
from tensorflow.keras.applications import (
    MobileNetV2, ResNet50V2, resnet_v2, 
    EfficientNetB1, efficientnet,
)
from tensorflow.keras.models import Model

from sklearn.manifold import TSNE
from sklearn.metrics import confusion_matrix, roc_curve, roc_auc_score, precision_recall_fscore_support, accuracy_score
from sklearn.model_selection import train_test_split

import seaborn as sns

# %%
# Script to assign and move files automatically to maps called train, val and test 
def move_images_with_labels(image_dir, target_dir, label):
    """
    #Move images from a source directory to the target directory while
    #labeling them as 'Negative' (0) or 'Positive' (1).
    
    #Parameters:
    #- image_dir: The source directory containing images.
    #- target_dir: The base directory where the images will be moved.
    #- label: The label for the class (0 for Negative, 1 for Positive).
    """
    images = [f for f in os.listdir(image_dir) if f.endswith('.jpg') or f.endswith('.png')]

    # Split images into train, validation, and test sets (60%, 20%, 20%)
    train_imgs, temp_imgs = train_test_split(images, test_size=0.4, random_state=42)
    val_imgs, test_imgs = train_test_split(temp_imgs, test_size=0.5, random_state=42)

    # Helper function to move images to the correct folder
    def move_to_folder(img_list, folder_name):
        for img in img_list:
            src_path = os.path.join(image_dir, img)
            dest_path = os.path.join(target_dir, folder_name, img)
            shutil.move(src_path, dest_path)
    
    # Create the necessary subfolders if they don't exist
    os.makedirs(os.path.join(target_dir, 'train', str(label)), exist_ok=True)
    os.makedirs(os.path.join(target_dir, 'val', str(label)), exist_ok=True)
    os.makedirs(os.path.join(target_dir, 'test', str(label)), exist_ok=True)

    # Move images to the respective folders with the correct label
    move_to_folder(train_imgs, 'train/' + str(label))
    move_to_folder(val_imgs, 'val/' + str(label))
    move_to_folder(test_imgs, 'test/' + str(label))

# Define directories for Positive and Negative images
positive_dir = 'Positive'  # Replace with your actual path
negative_dir = 'Negative'  # Replace with your actual path
target_dir = 'output_data'  # Replace with your actual target directory

# Move Positive and Negative images with labels
move_images_with_labels(positive_dir, target_dir, label=1)  # Label 1 for Positive
move_images_with_labels(negative_dir, target_dir, label=0)  # Label 0 for Negative

# %%
# Ensure reproducibility
np.random.seed(42)
tf.random.set_seed(42)

# Define paths
base_dir = "output_data"
train_dir = os.path.join(base_dir, "train")
val_dir = os.path.join(base_dir, "val")
test_dir = os.path.join(base_dir, "test")

# Defining hyperparameters
batch_size = 32
img_size = (227, 227)
epochs = 200

# %%
# Create tf.data Datasets from directory structure
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    train_dir,
    label_mode='binary',
    image_size=img_size,
    batch_size=batch_size,
    shuffle=True,
    seed=123
)

val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    val_dir,
    label_mode='binary',
    image_size=img_size,
    batch_size=batch_size,
    shuffle=True,
    seed=123
)

test_ds = tf.keras.preprocessing.image_dataset_from_directory(
    test_dir,
    label_mode='binary',
    image_size=img_size,
    batch_size=batch_size,
    shuffle=False
)
# Out:
# Found 5358 files belonging to 2 classes.
# Found 1786 files belonging to 2 classes.
# Found 1788 files belonging to 2 classes.

# %% [markdown]
# #### Exploratory Data Analysis:

# %%
## Visual Inspection:

def get_images_by_label(dataset, label, num_samples):
    """
    Retrieve `num_samples` images from the given `dataset` that match `label`.
    Returns a list of NumPy arrays.
    """
    images = []
    for img_batch, label_batch in dataset:
        for img, lbl in zip(img_batch, label_batch):
            if lbl == label:
                images.append(img.numpy().astype("uint8"))
                if len(images) >= num_samples:
                    return images
    return images

# Get 10 negative (0) and 10 positive (1) images
negative_images = get_images_by_label(val_ds, label=0, num_samples=10)
positive_images = get_images_by_label(val_ds, label=1, num_samples=10)

# Display them in a 2×10 grid
fig, axes = plt.subplots(2, 10, figsize=(15, 6))

for i, img in enumerate(negative_images):
    axes[0, i].imshow(img)
    axes[0, i].axis("off")
    axes[0, i].set_title("Negative")

for i, img in enumerate(positive_images):
    axes[1, i].imshow(img)
    axes[1, i].axis("off")
    axes[1, i].set_title("Positive")

plt.tight_layout()
plt.show()

# %%
# Generate summary statistics with class distribution

def summarize(ds, name):
    """
    Summarize and print number of cracked (c), uncracked (u) images, resolution and channels
    """
    c = u = 0
    res = ch = None
    for x, y in ds:
        y = y.numpy()
        c += (y == 1).sum()
        u += (y == 0).sum()
        if res is None:
            res = x.shape[1:3]
            ch = x.shape[3] if len(x.shape) == 4 else 1
    print(f"{name:10} | Cracked: {c:4} | Uncracked: {u:4} | Res: {res[0]}x{res[1]} | Channels: {ch}")

summarize(train_ds, "Train")
summarize(val_ds, "Validation")
summarize(test_ds, "Test")
# Out:
# Train      | Cracked: 2679 | Uncracked: 2679 | Res: 227x227 | Channels: 3
# Validation | Cracked:  893 | Uncracked:  893 | Res: 227x227 | Channels: 3
# Test       | Cracked:  894 | Uncracked:  894 | Res: 227x227 | Channels: 3

# %%
## t-SNE Visualization of Extracted Featurest-SNE Visualization of Extracted Features
#
# We will use **MobileNetV2** as a feature extractor (without its classifier). 
# Then we will run t-SNE on these extracted features to see if there are any natural clusters.

base_mobilenet = MobileNetV2(weights='imagenet', include_top=False, input_shape=(224, 224, 3))
feature_extractor = Model(
    inputs=base_mobilenet.input, 
    outputs=GlobalAveragePooling2D()(base_mobilenet.output)
)

def extract_features(dataset):
    """
    For each batch in `dataset`, resize images to (224, 224),
    extract features using `feature_extractor`,
    and collect labels.
    """
    all_features = []
    all_labels   = []
    for images, labels in dataset:
        # Resize images to match MobileNetV2 input
        resized = tf.image.resize(images, (224, 224))
        feats = feature_extractor.predict(resized, verbose=1)
        all_features.append(feats)
        all_labels.extend(labels.numpy())
    return np.vstack(all_features), np.array(all_labels)

# Extract features from the *training* dataset
train_features, train_labels = extract_features(train_ds)

# Perform t-SNE
tsne = TSNE(n_components=2, perplexity=30, random_state=42)
tsne_results = tsne.fit_transform(train_features)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 610ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 173ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 168ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 157ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 156ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 171ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 175ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 185ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 158ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 164ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 160ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 161ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 162ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 163ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 166ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 170ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 165ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 159ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 169ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 512ms/step

# %%
# Plot t-SNE visualization
plt.figure(figsize=(10, 6))
scatter = plt.scatter(
    tsne_results[:, 0], 
    tsne_results[:, 1], 
    c=train_labels, 
    cmap="coolwarm", 
    alpha=0.7,
    s = 0.3
)
plt.colorbar(label="Class Label")
plt.title("t-SNE Visualization of Training Image Embeddings")
plt.xlabel("t-SNE Component 1")
plt.ylabel("t-SNE Component 2")
plt.show()

# %% [markdown]
# #### Build and Train models

# %%
# Data Augumentation
preprocessing = keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"), # Flips pictures
    layers.RandomRotation(0.2),  # Rotates pictures rondomly (around ±72°)
    layers.RandomContrast(0.2),  # Random contrast adjustment
])

# %%
## ---------------------------------
## ResNet50V2
## ---------------------------------

resnet_base = ResNet50V2(include_top=False, weights='imagenet', input_shape=(227, 227, 3))
resnet_base.trainable = False 

resnet_model = keras.Sequential([
    layers.Input(shape=(227, 227, 3)),
    preprocessing,
    resnet_base,
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(1e-4)),
    layers.Dropout(0.35),
    layers.Dense(1, activation='sigmoid')
], name='ResNet50V2_model')

# %%
## ---------------------------------
## EfficientNetB1 Model
## ---------------------------------

effnet_base = EfficientNetB1(include_top=False, weights='imagenet', input_shape=(227, 227, 3))
effnet_base.trainable = False

effnet_model = keras.Sequential([
    layers.Input(shape=(227, 227, 3)),
    preprocessing,
    effnet_base,
    layers.GlobalAveragePooling2D(),
    layers.Dense(64, activation='relu', kernel_regularizer=keras.regularizers.l2(1e-4)),
    layers.Dropout(0.35),
    layers.Dense(1, activation='sigmoid')
], name='EfficientNetB1_model')

# %%
## ---------------------------------
## Custom CNN
## ---------------------------------

custom_model = keras.Sequential([
    layers.Input(shape=(227, 227, 3)),
    preprocessing,

    layers.Conv2D(16, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(32, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Conv2D(64, 3, activation='relu'),
    layers.BatchNormalization(),
    layers.MaxPooling2D(2),

    layers.Flatten(),
    layers.Dense(64, activation='relu'),
    layers.Dropout(0.35),
    layers.Dense(1, activation='sigmoid')
], name='Custom_model')

# %%
# Preprocessing

AUTOTUNE = tf.data.AUTOTUNE

def resnet_preprocess(x, y):
    return resnet_v2.preprocess_input(x), y  # Normalize images, keep labels unchanged

# For the custom model, simple rescaling is sufficient
def simple_rescaling(x, y):
    x = tf.cast(x, tf.float32) / 255.0
    return x, y

# Apply preprocessing inside a `map()`
train_ds_resnet = train_ds.map(lambda x, y: resnet_preprocess(x, y)).cache().prefetch(AUTOTUNE)
val_ds_resnet = val_ds.map(lambda x, y: resnet_preprocess(x, y)).cache().prefetch(AUTOTUNE)
test_ds_resnet = test_ds.map(lambda x, y: resnet_preprocess(x, y)).cache().prefetch(AUTOTUNE)

train_ds_custom = train_ds.map(simple_rescaling).cache().prefetch(AUTOTUNE)
val_ds_custom   = val_ds.map(simple_rescaling).cache().prefetch(AUTOTUNE)
test_ds_custom   = test_ds.map(simple_rescaling).cache().prefetch(AUTOTUNE)

# %%
# Compile all models
models = [resnet_model, effnet_model, custom_model]
for m in models:
    m.compile(
        optimizer=keras.optimizers.Adam(learning_rate=1e-3),
        loss='binary_crossentropy',
        metrics=[keras.metrics.BinaryAccuracy()]
    )

# Base callbacks
callbacks_template = [
    keras.callbacks.EarlyStopping(monitor='val_loss', patience=7, restore_best_weights=True),
    keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=3, min_lr=1e-6)
]

# Training function
def train_model(model, train_ds, val_ds, model_name, epochs):
    print(f"Training {model_name}...")
    callbacks = callbacks_template + [
        keras.callbacks.ModelCheckpoint(
            filepath=f"best_{model_name.lower()}_model.keras",
            monitor='val_binary_accuracy',
            save_best_only=True,
            verbose=1
        )
    ]
    history = model.fit(
        train_ds,
        validation_data=val_ds,
        epochs=epochs,
        callbacks=callbacks
    )
    return history

# Train all models
model_configs = [
    (resnet_model, train_ds_resnet, val_ds_resnet, "ResNet50V2"),
    (effnet_model, train_ds, val_ds, "EfficientNetB1"),
    (custom_model, train_ds_custom, val_ds_custom, "Custom CNN")
]

histories = {}
for model, train_ds, val_ds, name in model_configs:
    histories[name] = train_model(model, train_ds, val_ds, name, epochs)
# Out:
# Training ResNet50V2...
# Epoch 1/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - binary_accuracy: 0.8836 - loss: 0.2799
# Epoch 1: val_binary_accuracy improved from -inf to 0.98096, saving model to best_resnet50v2_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 407ms/step - binary_accuracy: 0.8838 - loss: 0.2795 - val_binary_accuracy: 0.9810 - val_loss: 0.0604 - learning_rate: 0.0010
# Epoch 2/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9449 - loss: 0.1549
# Epoch 2: val_binary_accuracy improved from 0.98096 to 0.98320, saving model to best_resnet50v2_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 66s 391ms/step - binary_accuracy: 0.9449 - loss: 0.1549 - val_binary_accuracy: 0.9832 - val_loss: 0.0584 - learning_rate: 0.0010
# Epoch 3/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - binary_accuracy: 0.9471 - loss: 0.1499
# Epoch 3: val_binary_accuracy did not improve from 0.98320
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 66s 391ms/step - binary_accuracy: 0.9471 - loss: 0.1499 - val_binary_accuracy: 0.9832 - val_loss: 0.0557 - learning_rate: 0.0010
# Epoch 4/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step - binary_accuracy: 0.9455 - loss: 0.1405
# Epoch 4: val_binary_accuracy improved from 0.98320 to 0.98488, saving model to best_resnet50v2_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 68s 403ms/step - binary_accuracy: 0.9455 - loss: 0.1405 - val_binary_accuracy: 0.9849 - val_loss: 0.0509 - learning_rate: 0.0010
# Epoch 5/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - binary_accuracy: 0.9495 - loss: 0.1365
# Epoch 5: val_binary_accuracy did not improve from 0.98488
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 390ms/step - binary_accuracy: 0.9495 - loss: 0.1365 - val_binary_accuracy: 0.9804 - val_loss: 0.0547 - learning_rate: 0.0010
# Epoch 6/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - binary_accuracy: 0.9498 - loss: 0.1381
# Epoch 6: val_binary_accuracy did not improve from 0.98488
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 386ms/step - binary_accuracy: 0.9498 - loss: 0.1381 - val_binary_accuracy: 0.9843 - val_loss: 0.0526 - learning_rate: 0.0010
# Epoch 7/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9509 - loss: 0.1345
# Epoch 7: val_binary_accuracy did not improve from 0.98488
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 387ms/step - binary_accuracy: 0.9509 - loss: 0.1345 - val_binary_accuracy: 0.9815 - val_loss: 0.0548 - learning_rate: 0.0010
# Epoch 8/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9563 - loss: 0.1248
# Epoch 8: val_binary_accuracy did not improve from 0.98488
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 384ms/step - binary_accuracy: 0.9563 - loss: 0.1248 - val_binary_accuracy: 0.9804 - val_loss: 0.0571 - learning_rate: 5.0000e-04
# Epoch 9/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9566 - loss: 0.1196
# Epoch 9: val_binary_accuracy improved from 0.98488 to 0.98600, saving model to best_resnet50v2_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 388ms/step - binary_accuracy: 0.9566 - loss: 0.1196 - val_binary_accuracy: 0.9860 - val_loss: 0.0480 - learning_rate: 5.0000e-04
# Epoch 10/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9574 - loss: 0.1150
# Epoch 10: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 386ms/step - binary_accuracy: 0.9574 - loss: 0.1150 - val_binary_accuracy: 0.9860 - val_loss: 0.0479 - learning_rate: 5.0000e-04
# Epoch 11/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step - binary_accuracy: 0.9590 - loss: 0.1172
# Epoch 11: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 386ms/step - binary_accuracy: 0.9589 - loss: 0.1172 - val_binary_accuracy: 0.9843 - val_loss: 0.0506 - learning_rate: 5.0000e-04
# Epoch 12/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9558 - loss: 0.1179
# Epoch 12: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 387ms/step - binary_accuracy: 0.9558 - loss: 0.1179 - val_binary_accuracy: 0.9821 - val_loss: 0.0524 - learning_rate: 5.0000e-04
# Epoch 13/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step - binary_accuracy: 0.9563 - loss: 0.1214
# Epoch 13: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 385ms/step - binary_accuracy: 0.9563 - loss: 0.1214 - val_binary_accuracy: 0.9843 - val_loss: 0.0506 - learning_rate: 2.5000e-04
# Epoch 14/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9583 - loss: 0.1139
# Epoch 14: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 387ms/step - binary_accuracy: 0.9583 - loss: 0.1139 - val_binary_accuracy: 0.9838 - val_loss: 0.0481 - learning_rate: 2.5000e-04
# Epoch 15/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9617 - loss: 0.1111
# Epoch 15: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 386ms/step - binary_accuracy: 0.9617 - loss: 0.1110 - val_binary_accuracy: 0.9832 - val_loss: 0.0486 - learning_rate: 2.5000e-04
# Epoch 16/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9608 - loss: 0.1132
# Epoch 16: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 387ms/step - binary_accuracy: 0.9608 - loss: 0.1132 - val_binary_accuracy: 0.9838 - val_loss: 0.0471 - learning_rate: 1.2500e-04
# Epoch 17/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9599 - loss: 0.1132
# Epoch 17: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 388ms/step - binary_accuracy: 0.9599 - loss: 0.1132 - val_binary_accuracy: 0.9826 - val_loss: 0.0479 - learning_rate: 1.2500e-04
# Epoch 18/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9594 - loss: 0.1112
# Epoch 18: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 387ms/step - binary_accuracy: 0.9594 - loss: 0.1112 - val_binary_accuracy: 0.9821 - val_loss: 0.0504 - learning_rate: 1.2500e-04
# Epoch 19/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step - binary_accuracy: 0.9609 - loss: 0.1118
# Epoch 19: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 387ms/step - binary_accuracy: 0.9609 - loss: 0.1118 - val_binary_accuracy: 0.9843 - val_loss: 0.0504 - learning_rate: 1.2500e-04
# Epoch 20/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - binary_accuracy: 0.9609 - loss: 0.1102
# Epoch 20: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 389ms/step - binary_accuracy: 0.9609 - loss: 0.1102 - val_binary_accuracy: 0.9832 - val_loss: 0.0480 - learning_rate: 6.2500e-05
# Epoch 21/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step - binary_accuracy: 0.9627 - loss: 0.1071
# Epoch 21: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 389ms/step - binary_accuracy: 0.9627 - loss: 0.1071 - val_binary_accuracy: 0.9838 - val_loss: 0.0475 - learning_rate: 6.2500e-05
# Epoch 22/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step - binary_accuracy: 0.9635 - loss: 0.1071
# Epoch 22: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 65s 390ms/step - binary_accuracy: 0.9635 - loss: 0.1071 - val_binary_accuracy: 0.9832 - val_loss: 0.0481 - learning_rate: 6.2500e-05
# Epoch 23/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step - binary_accuracy: 0.9640 - loss: 0.1072
# Epoch 23: val_binary_accuracy did not improve from 0.98600
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 66s 392ms/step - binary_accuracy: 0.9640 - loss: 0.1072 - val_binary_accuracy: 0.9838 - val_loss: 0.0479 - learning_rate: 3.1250e-05
# Training EfficientNetB1...
# Epoch 1/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - binary_accuracy: 0.9053 - loss: 0.2527
# Epoch 1: val_binary_accuracy improved from -inf to 0.95577, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 78s 432ms/step - binary_accuracy: 0.9055 - loss: 0.2522 - val_binary_accuracy: 0.9558 - val_loss: 0.1210 - learning_rate: 0.0010
# Epoch 2/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step - binary_accuracy: 0.9697 - loss: 0.1013
# Epoch 2: val_binary_accuracy improved from 0.95577 to 0.97368, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 70s 415ms/step - binary_accuracy: 0.9697 - loss: 0.1013 - val_binary_accuracy: 0.9737 - val_loss: 0.0823 - learning_rate: 0.0010
# Epoch 3/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - binary_accuracy: 0.9702 - loss: 0.0877
# Epoch 3: val_binary_accuracy improved from 0.97368 to 0.98320, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 70s 418ms/step - binary_accuracy: 0.9702 - loss: 0.0876 - val_binary_accuracy: 0.9832 - val_loss: 0.0621 - learning_rate: 0.0010
# Epoch 4/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 321ms/step - binary_accuracy: 0.9742 - loss: 0.0835
# Epoch 4: val_binary_accuracy improved from 0.98320 to 0.98544, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 420ms/step - binary_accuracy: 0.9742 - loss: 0.0835 - val_binary_accuracy: 0.9854 - val_loss: 0.0594 - learning_rate: 0.0010
# Epoch 5/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - binary_accuracy: 0.9806 - loss: 0.0727
# Epoch 5: val_binary_accuracy improved from 0.98544 to 0.98656, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 424ms/step - binary_accuracy: 0.9806 - loss: 0.0727 - val_binary_accuracy: 0.9866 - val_loss: 0.0562 - learning_rate: 0.0010
# Epoch 6/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - binary_accuracy: 0.9825 - loss: 0.0646
# Epoch 6: val_binary_accuracy did not improve from 0.98656
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 423ms/step - binary_accuracy: 0.9825 - loss: 0.0646 - val_binary_accuracy: 0.9854 - val_loss: 0.0642 - learning_rate: 0.0010
# Epoch 7/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step - binary_accuracy: 0.9791 - loss: 0.0739
# Epoch 7: val_binary_accuracy improved from 0.98656 to 0.98880, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 70s 418ms/step - binary_accuracy: 0.9791 - loss: 0.0739 - val_binary_accuracy: 0.9888 - val_loss: 0.0552 - learning_rate: 0.0010
# Epoch 8/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - binary_accuracy: 0.9822 - loss: 0.0697
# Epoch 8: val_binary_accuracy improved from 0.98880 to 0.99048, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 426ms/step - binary_accuracy: 0.9822 - loss: 0.0697 - val_binary_accuracy: 0.9905 - val_loss: 0.0512 - learning_rate: 0.0010
# Epoch 9/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - binary_accuracy: 0.9794 - loss: 0.0708
# Epoch 9: val_binary_accuracy did not improve from 0.99048
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 425ms/step - binary_accuracy: 0.9794 - loss: 0.0709 - val_binary_accuracy: 0.9871 - val_loss: 0.0551 - learning_rate: 0.0010
# Epoch 10/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - binary_accuracy: 0.9814 - loss: 0.0636
# Epoch 10: val_binary_accuracy did not improve from 0.99048
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 426ms/step - binary_accuracy: 0.9814 - loss: 0.0636 - val_binary_accuracy: 0.9899 - val_loss: 0.0517 - learning_rate: 0.0010
# Epoch 11/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - binary_accuracy: 0.9853 - loss: 0.0613
# Epoch 11: val_binary_accuracy did not improve from 0.99048
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 421ms/step - binary_accuracy: 0.9853 - loss: 0.0613 - val_binary_accuracy: 0.9798 - val_loss: 0.0699 - learning_rate: 0.0010
# Epoch 12/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - binary_accuracy: 0.9830 - loss: 0.0659
# Epoch 12: val_binary_accuracy improved from 0.99048 to 0.99160, saving model to best_efficientnetb1_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 429ms/step - binary_accuracy: 0.9830 - loss: 0.0659 - val_binary_accuracy: 0.9916 - val_loss: 0.0482 - learning_rate: 5.0000e-04
# Epoch 13/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - binary_accuracy: 0.9842 - loss: 0.0577
# Epoch 13: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 70s 419ms/step - binary_accuracy: 0.9842 - loss: 0.0577 - val_binary_accuracy: 0.9916 - val_loss: 0.0463 - learning_rate: 5.0000e-04
# Epoch 14/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - binary_accuracy: 0.9828 - loss: 0.0591
# Epoch 14: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 425ms/step - binary_accuracy: 0.9828 - loss: 0.0591 - val_binary_accuracy: 0.9882 - val_loss: 0.0494 - learning_rate: 5.0000e-04
# Epoch 15/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - binary_accuracy: 0.9844 - loss: 0.0591
# Epoch 15: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 423ms/step - binary_accuracy: 0.9844 - loss: 0.0590 - val_binary_accuracy: 0.9916 - val_loss: 0.0473 - learning_rate: 5.0000e-04
# Epoch 16/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - binary_accuracy: 0.9865 - loss: 0.0546
# Epoch 16: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 70s 419ms/step - binary_accuracy: 0.9865 - loss: 0.0546 - val_binary_accuracy: 0.9888 - val_loss: 0.0476 - learning_rate: 5.0000e-04
# Epoch 17/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 322ms/step - binary_accuracy: 0.9903 - loss: 0.0503
# Epoch 17: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 420ms/step - binary_accuracy: 0.9903 - loss: 0.0504 - val_binary_accuracy: 0.9905 - val_loss: 0.0455 - learning_rate: 2.5000e-04
# Epoch 18/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - binary_accuracy: 0.9843 - loss: 0.0597
# Epoch 18: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 422ms/step - binary_accuracy: 0.9843 - loss: 0.0596 - val_binary_accuracy: 0.9910 - val_loss: 0.0457 - learning_rate: 2.5000e-04
# Epoch 19/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 324ms/step - binary_accuracy: 0.9845 - loss: 0.0524
# Epoch 19: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 423ms/step - binary_accuracy: 0.9845 - loss: 0.0524 - val_binary_accuracy: 0.9910 - val_loss: 0.0459 - learning_rate: 2.5000e-04
# Epoch 20/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 325ms/step - binary_accuracy: 0.9896 - loss: 0.0488
# Epoch 20: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 424ms/step - binary_accuracy: 0.9896 - loss: 0.0488 - val_binary_accuracy: 0.9877 - val_loss: 0.0471 - learning_rate: 2.5000e-04
# Epoch 21/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 323ms/step - binary_accuracy: 0.9906 - loss: 0.0453
# Epoch 21: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 421ms/step - binary_accuracy: 0.9906 - loss: 0.0453 - val_binary_accuracy: 0.9894 - val_loss: 0.0451 - learning_rate: 1.2500e-04
# Epoch 22/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - binary_accuracy: 0.9884 - loss: 0.0468
# Epoch 22: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 424ms/step - binary_accuracy: 0.9884 - loss: 0.0468 - val_binary_accuracy: 0.9905 - val_loss: 0.0452 - learning_rate: 1.2500e-04
# Epoch 23/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 326ms/step - binary_accuracy: 0.9914 - loss: 0.0423
# Epoch 23: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 424ms/step - binary_accuracy: 0.9914 - loss: 0.0423 - val_binary_accuracy: 0.9905 - val_loss: 0.0452 - learning_rate: 1.2500e-04
# Epoch 24/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - binary_accuracy: 0.9902 - loss: 0.0420
# Epoch 24: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 425ms/step - binary_accuracy: 0.9902 - loss: 0.0420 - val_binary_accuracy: 0.9910 - val_loss: 0.0447 - learning_rate: 1.2500e-04
# Epoch 25/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 328ms/step - binary_accuracy: 0.9918 - loss: 0.0428
# Epoch 25: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 426ms/step - binary_accuracy: 0.9918 - loss: 0.0428 - val_binary_accuracy: 0.9905 - val_loss: 0.0453 - learning_rate: 1.2500e-04
# Epoch 26/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 327ms/step - binary_accuracy: 0.9863 - loss: 0.0465
# Epoch 26: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 71s 425ms/step - binary_accuracy: 0.9863 - loss: 0.0465 - val_binary_accuracy: 0.9894 - val_loss: 0.0451 - learning_rate: 1.2500e-04
# Epoch 27/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 329ms/step - binary_accuracy: 0.9898 - loss: 0.0476
# Epoch 27: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 427ms/step - binary_accuracy: 0.9898 - loss: 0.0476 - val_binary_accuracy: 0.9905 - val_loss: 0.0437 - learning_rate: 1.2500e-04
# Epoch 28/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - binary_accuracy: 0.9887 - loss: 0.0466
# Epoch 28: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 431ms/step - binary_accuracy: 0.9887 - loss: 0.0466 - val_binary_accuracy: 0.9905 - val_loss: 0.0439 - learning_rate: 1.2500e-04
# Epoch 29/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - binary_accuracy: 0.9879 - loss: 0.0445
# Epoch 29: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 431ms/step - binary_accuracy: 0.9879 - loss: 0.0446 - val_binary_accuracy: 0.9910 - val_loss: 0.0440 - learning_rate: 1.2500e-04
# Epoch 30/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - binary_accuracy: 0.9911 - loss: 0.0430
# Epoch 30: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 433ms/step - binary_accuracy: 0.9911 - loss: 0.0430 - val_binary_accuracy: 0.9905 - val_loss: 0.0447 - learning_rate: 1.2500e-04
# Epoch 31/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - binary_accuracy: 0.9911 - loss: 0.0426
# Epoch 31: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 432ms/step - binary_accuracy: 0.9910 - loss: 0.0426 - val_binary_accuracy: 0.9888 - val_loss: 0.0449 - learning_rate: 6.2500e-05
# Epoch 32/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - binary_accuracy: 0.9897 - loss: 0.0504
# Epoch 32: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 431ms/step - binary_accuracy: 0.9897 - loss: 0.0504 - val_binary_accuracy: 0.9905 - val_loss: 0.0440 - learning_rate: 6.2500e-05
# Epoch 33/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - binary_accuracy: 0.9936 - loss: 0.0377
# Epoch 33: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 435ms/step - binary_accuracy: 0.9936 - loss: 0.0377 - val_binary_accuracy: 0.9888 - val_loss: 0.0437 - learning_rate: 6.2500e-05
# Epoch 34/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 344ms/step - binary_accuracy: 0.9884 - loss: 0.0454
# Epoch 34: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 75s 446ms/step - binary_accuracy: 0.9884 - loss: 0.0454 - val_binary_accuracy: 0.9882 - val_loss: 0.0444 - learning_rate: 3.1250e-05
# Epoch 35/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 334ms/step - binary_accuracy: 0.9905 - loss: 0.0443
# Epoch 35: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 433ms/step - binary_accuracy: 0.9905 - loss: 0.0443 - val_binary_accuracy: 0.9894 - val_loss: 0.0437 - learning_rate: 3.1250e-05
# Epoch 36/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - binary_accuracy: 0.9882 - loss: 0.0431
# Epoch 36: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 432ms/step - binary_accuracy: 0.9882 - loss: 0.0431 - val_binary_accuracy: 0.9882 - val_loss: 0.0442 - learning_rate: 3.1250e-05
# Epoch 37/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 335ms/step - binary_accuracy: 0.9916 - loss: 0.0411
# Epoch 37: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 434ms/step - binary_accuracy: 0.9916 - loss: 0.0411 - val_binary_accuracy: 0.9888 - val_loss: 0.0440 - learning_rate: 1.5625e-05
# Epoch 38/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 333ms/step - binary_accuracy: 0.9910 - loss: 0.0451
# Epoch 38: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 73s 432ms/step - binary_accuracy: 0.9910 - loss: 0.0451 - val_binary_accuracy: 0.9888 - val_loss: 0.0439 - learning_rate: 1.5625e-05
# Epoch 39/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 332ms/step - binary_accuracy: 0.9901 - loss: 0.0418
# Epoch 39: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 431ms/step - binary_accuracy: 0.9901 - loss: 0.0418 - val_binary_accuracy: 0.9882 - val_loss: 0.0441 - learning_rate: 1.5625e-05
# Epoch 40/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 331ms/step - binary_accuracy: 0.9922 - loss: 0.0377
# Epoch 40: val_binary_accuracy did not improve from 0.99160
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 72s 430ms/step - binary_accuracy: 0.9922 - loss: 0.0377 - val_binary_accuracy: 0.9888 - val_loss: 0.0437 - learning_rate: 7.8125e-06
# Training Custom CNN...
# Epoch 1/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 211ms/step - binary_accuracy: 0.6753 - loss: 4.5937
# Epoch 1: val_binary_accuracy improved from -inf to 0.61982, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 39s 224ms/step - binary_accuracy: 0.6754 - loss: 4.5804 - val_binary_accuracy: 0.6198 - val_loss: 1.2385 - learning_rate: 0.0010
# Epoch 2/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - binary_accuracy: 0.7635 - loss: 0.4895
# Epoch 2: val_binary_accuracy did not improve from 0.61982
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 213ms/step - binary_accuracy: 0.7635 - loss: 0.4896 - val_binary_accuracy: 0.5274 - val_loss: 5.4810 - learning_rate: 0.0010
# Epoch 3/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - binary_accuracy: 0.7795 - loss: 0.4420
# Epoch 3: val_binary_accuracy did not improve from 0.61982
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 210ms/step - binary_accuracy: 0.7795 - loss: 0.4420 - val_binary_accuracy: 0.5398 - val_loss: 1.3949 - learning_rate: 0.0010
# Epoch 4/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.7908 - loss: 0.4058
# Epoch 4: val_binary_accuracy improved from 0.61982 to 0.72956, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.7909 - loss: 0.4057 - val_binary_accuracy: 0.7296 - val_loss: 1.2325 - learning_rate: 0.0010
# Epoch 5/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8166 - loss: 0.3872
# Epoch 5: val_binary_accuracy improved from 0.72956 to 0.76204, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 211ms/step - binary_accuracy: 0.8165 - loss: 0.3874 - val_binary_accuracy: 0.7620 - val_loss: 0.5105 - learning_rate: 0.0010
# Epoch 6/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.7954 - loss: 0.4870
# Epoch 6: val_binary_accuracy improved from 0.76204 to 0.80123, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 211ms/step - binary_accuracy: 0.7954 - loss: 0.4867 - val_binary_accuracy: 0.8012 - val_loss: 0.4749 - learning_rate: 0.0010
# Epoch 7/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - binary_accuracy: 0.8296 - loss: 0.4005
# Epoch 7: val_binary_accuracy improved from 0.80123 to 0.81075, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.8296 - loss: 0.4004 - val_binary_accuracy: 0.8108 - val_loss: 0.4422 - learning_rate: 0.0010
# Epoch 8/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8450 - loss: 0.3439
# Epoch 8: val_binary_accuracy did not improve from 0.81075
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.8450 - loss: 0.3440 - val_binary_accuracy: 0.8091 - val_loss: 0.3883 - learning_rate: 0.0010
# Epoch 9/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8447 - loss: 0.3468
# Epoch 9: val_binary_accuracy did not improve from 0.81075
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.8447 - loss: 0.3468 - val_binary_accuracy: 0.6361 - val_loss: 0.9158 - learning_rate: 0.0010
# Epoch 10/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8637 - loss: 0.3272
# Epoch 10: val_binary_accuracy did not improve from 0.81075
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.8637 - loss: 0.3272 - val_binary_accuracy: 0.8035 - val_loss: 0.4719 - learning_rate: 0.0010
# Epoch 11/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8782 - loss: 0.2920
# Epoch 11: val_binary_accuracy improved from 0.81075 to 0.86730, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.8782 - loss: 0.2921 - val_binary_accuracy: 0.8673 - val_loss: 0.3342 - learning_rate: 0.0010
# Epoch 12/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8627 - loss: 0.2977
# Epoch 12: val_binary_accuracy did not improve from 0.86730
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.8627 - loss: 0.2977 - val_binary_accuracy: 0.5140 - val_loss: 14.6668 - learning_rate: 0.0010
# Epoch 13/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - binary_accuracy: 0.8719 - loss: 0.3032
# Epoch 13: val_binary_accuracy did not improve from 0.86730
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 210ms/step - binary_accuracy: 0.8719 - loss: 0.3031 - val_binary_accuracy: 0.8466 - val_loss: 0.4544 - learning_rate: 0.0010
# Epoch 14/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.8857 - loss: 0.2459
# Epoch 14: val_binary_accuracy improved from 0.86730 to 0.92049, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 211ms/step - binary_accuracy: 0.8857 - loss: 0.2460 - val_binary_accuracy: 0.9205 - val_loss: 0.2109 - learning_rate: 0.0010
# Epoch 15/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 201ms/step - binary_accuracy: 0.8964 - loss: 0.2577
# Epoch 15: val_binary_accuracy did not improve from 0.92049
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 210ms/step - binary_accuracy: 0.8964 - loss: 0.2578 - val_binary_accuracy: 0.8063 - val_loss: 0.3899 - learning_rate: 0.0010
# Epoch 16/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9072 - loss: 0.2279
# Epoch 16: val_binary_accuracy did not improve from 0.92049
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.9072 - loss: 0.2279 - val_binary_accuracy: 0.8074 - val_loss: 0.3853 - learning_rate: 0.0010
# Epoch 17/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9077 - loss: 0.2432
# Epoch 17: val_binary_accuracy did not improve from 0.92049
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 210ms/step - binary_accuracy: 0.9076 - loss: 0.2432 - val_binary_accuracy: 0.8841 - val_loss: 0.2655 - learning_rate: 0.0010
# Epoch 18/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9233 - loss: 0.1829
# Epoch 18: val_binary_accuracy did not improve from 0.92049
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 212ms/step - binary_accuracy: 0.9233 - loss: 0.1829 - val_binary_accuracy: 0.8651 - val_loss: 0.3138 - learning_rate: 5.0000e-04
# Epoch 19/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9321 - loss: 0.1815
# Epoch 19: val_binary_accuracy improved from 0.92049 to 0.94121, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 212ms/step - binary_accuracy: 0.9320 - loss: 0.1815 - val_binary_accuracy: 0.9412 - val_loss: 0.1917 - learning_rate: 5.0000e-04
# Epoch 20/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9323 - loss: 0.1745
# Epoch 20: val_binary_accuracy did not improve from 0.94121
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.9323 - loss: 0.1745 - val_binary_accuracy: 0.8914 - val_loss: 0.2893 - learning_rate: 5.0000e-04
# Epoch 21/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9357 - loss: 0.1549
# Epoch 21: val_binary_accuracy did not improve from 0.94121
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.9357 - loss: 0.1549 - val_binary_accuracy: 0.8550 - val_loss: 0.6439 - learning_rate: 5.0000e-04
# Epoch 22/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9399 - loss: 0.1491
# Epoch 22: val_binary_accuracy did not improve from 0.94121
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 35s 211ms/step - binary_accuracy: 0.9399 - loss: 0.1492 - val_binary_accuracy: 0.7626 - val_loss: 1.2093 - learning_rate: 5.0000e-04
# Epoch 23/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 205ms/step - binary_accuracy: 0.9467 - loss: 0.1413
# Epoch 23: val_binary_accuracy improved from 0.94121 to 0.96697, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 215ms/step - binary_accuracy: 0.9467 - loss: 0.1413 - val_binary_accuracy: 0.9670 - val_loss: 0.0843 - learning_rate: 2.5000e-04
# Epoch 24/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - binary_accuracy: 0.9517 - loss: 0.1260
# Epoch 24: val_binary_accuracy did not improve from 0.96697
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 215ms/step - binary_accuracy: 0.9517 - loss: 0.1260 - val_binary_accuracy: 0.9580 - val_loss: 0.1291 - learning_rate: 2.5000e-04
# Epoch 25/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - binary_accuracy: 0.9531 - loss: 0.1196
# Epoch 25: val_binary_accuracy did not improve from 0.96697
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 212ms/step - binary_accuracy: 0.9531 - loss: 0.1197 - val_binary_accuracy: 0.9418 - val_loss: 0.1532 - learning_rate: 2.5000e-04
# Epoch 26/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 204ms/step - binary_accuracy: 0.9517 - loss: 0.1243
# Epoch 26: val_binary_accuracy did not improve from 0.96697
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 213ms/step - binary_accuracy: 0.9517 - loss: 0.1243 - val_binary_accuracy: 0.9367 - val_loss: 0.2159 - learning_rate: 2.5000e-04
# Epoch 27/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - binary_accuracy: 0.9558 - loss: 0.1160
# Epoch 27: val_binary_accuracy did not improve from 0.96697
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 212ms/step - binary_accuracy: 0.9558 - loss: 0.1160 - val_binary_accuracy: 0.9670 - val_loss: 0.0897 - learning_rate: 1.2500e-04
# Epoch 28/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 203ms/step - binary_accuracy: 0.9582 - loss: 0.1061
# Epoch 28: val_binary_accuracy did not improve from 0.96697
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 212ms/step - binary_accuracy: 0.9582 - loss: 0.1061 - val_binary_accuracy: 0.9658 - val_loss: 0.0917 - learning_rate: 1.2500e-04
# Epoch 29/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 202ms/step - binary_accuracy: 0.9639 - loss: 0.0954
# Epoch 29: val_binary_accuracy did not improve from 0.96697
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 211ms/step - binary_accuracy: 0.9639 - loss: 0.0955 - val_binary_accuracy: 0.9664 - val_loss: 0.0985 - learning_rate: 1.2500e-04
# Epoch 30/200
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 0s 206ms/step - binary_accuracy: 0.9624 - loss: 0.1067
# Epoch 30: val_binary_accuracy improved from 0.96697 to 0.96865, saving model to best_custom cnn_model.keras
# 168/168 ━━━━━━━━━━━━━━━━━━━━ 36s 216ms/step - binary_accuracy: 0.9624 - loss: 0.1067 - val_binary_accuracy: 0.9686 - val_loss: 0.1037 - learning_rate: 6.2500e-05

# %% [markdown]
# Evaluate Model Performance with Confusion Matrices and ROC Curves

# %%
# Dictionary to store results for each model
model_results = {}

# List of models with associated test dataset
models_dict = {
    "ResNet50V2": (resnet_model, test_ds_resnet),
    "EfficientNetB1": (effnet_model, test_ds),
    "Custom": (custom_model, test_ds_custom)
}

for model_name, (model, test_dataset) in models_dict.items():
    print(f"Evaluating {model_name}...")
    
    # Get true labels and predictions (probabilities)
    y_true = []
    y_probs = []
    for images, labels in test_dataset:
        probs = model.predict(images).flatten()
        y_probs.extend(probs)
        y_true.extend(labels.numpy())
    
    y_true = np.array(y_true)
    y_probs = np.array(y_probs)
    
    # Convert probabilities to binary predictions (using 0.5 threshold)
    y_pred = (y_probs > 0.5).astype(int)
    
    # Compute confusion matrix
    cm = confusion_matrix(y_true, y_pred)
    
    # Plot confusion matrix using seaborn heatmap
    plt.figure(figsize=(3, 2))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=['No-Crack', 'Crack'], 
                yticklabels=['No-Crack', 'Crack'])
    plt.title(f'Confusion Matrix - {model_name}')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()
    
    # Compute ROC curve and AUC
    fpr, tpr, thresholds = roc_curve(y_true, y_probs)
    auc_score = roc_auc_score(y_true, y_probs)
    
    # Plot ROC curve
    plt.figure(figsize=(6, 4))
    plt.plot(fpr, tpr, label=f'{model_name} ROC (AUC = {auc_score:.4f})')
    plt.plot([0, 1], [0, 1], 'k--', label='Random Guess')
    plt.title(f'ROC Curve - {model_name}')
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.legend(loc='lower right')
    plt.grid(True)
    plt.show()
    
    # Compute Accuracy, Precision, Recall, and F1-score
    accuracy = accuracy_score(y_true, y_pred)
    precision, recall, f1, _ = precision_recall_fscore_support(y_true, y_pred, average='binary')
    print(f"{model_name} - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1-Score: {f1:.4f}\n")
    
    # Store results in dictionary
    model_results[model_name] = {
        "confusion_matrix": cm,
        "fpr": fpr,
        "tpr": tpr,
        "auc": auc_score,
        "accuracy": accuracy,
        "precision": precision,
        "recall": recall,
        "f1_score": f1
    }
# Out:
# Evaluating ResNet50V2...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 319ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 318ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 316ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 317ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 293ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 292ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 294ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 272ms/step
# ResNet50V2 - Accuracy: 0.9855, Precision: 0.9898, Recall: 0.9810, F1-Score: 0.9854
#
# Evaluating EfficientNetB1...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 315ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 311ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 314ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 309ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 313ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 306ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 307ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 308ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 303ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 305ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 304ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 298ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 302ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 297ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 299ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 296ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 301ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 300ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 295ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 1s/step
# EfficientNetB1 - Accuracy: 0.9899, Precision: 0.9989, Recall: 0.9810, F1-Score: 0.9898
#
# Evaluating Custom...
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 154ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 42ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 43ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 45ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 44ms/step
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 90ms/step
# Custom - Accuracy: 0.9704, Precision: 0.9839, Recall: 0.9564, F1-Score: 0.9699
